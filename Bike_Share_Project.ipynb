# %% [markdown]
# <a href="https://colab.research.google.com/github/Rpvermaak/bike-share-project/blob/main/Bike_Share_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2025-03-09 at 2.56.14 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Cyclistic bike-share analysis case study
#
# ## Scenario:
#
# You are a junior data analyst working on the marketing analyst team at Cyclistic, a bike-share
# company in Chicago. The director of marketing believes the company’s future success
# depends on maximizing the number of annual memberships. Therefore, your team wants to
# understand how casual riders and annual members use Cyclistic bikes differently. From these
# insights, your team will design a new marketing strategy to convert casual riders into annual
# members. But first, Cyclistic executives must approve your recommendations, so they must be
# backed up with compelling data insights and professional data visualizations.
#
# Three questions will guide the future marketing program:
# 1. How do annual members and casual riders use Cyclistic bikes differently?
# 2. Why would casual riders buy Cyclistic annual memberships?
# 3. How can Cyclistic use digital media to influence casual riders to become members?
#
# The director of marketing assigned me the first question to answer: 1. How do annual members and casual riders use Cyclistic bikes differently?
#
# ## ASk; Phase
#
# ##Business Task:
#
# Analyze Cyclistic's historical trip data to identify statistically significant differences in how annual members and casual riders utilize the bike-share service. Present actionable insights and visualizations that highlight these differences to inform a targeted marketing strategy aimed at converting casual riders into annual members.
#
# **Data Description**:
# I will utilize historical trip data, from January 2024 - Decemeber 2024.Provided by Cyclistic, a bike-share company in Chicago. This data represents individual bike trips taken by both casual riders and annual members over a twelve-month period. Data license agreement: https://divvybikes.com/data-license-agreement
#
# **Key Characteristics of the Data**:
#
# **Trip-Level Data**: Each row in the dataset represents a single bike trip, capturing details about that specific ride.
#
# **Time-Stamped Information**: The data includes precise timestamps for the start and end of each trip, enabling me to analyze trip duration and time-based usage patterns.
#
# **Station Information**: The data contains information about the starting and ending stations for each trip, allowing me to examine popular routes and station usage.
#
# **User Type**: A crucial element is the identification of the rider as either a "casual rider" (single-ride or full-day pass) or an "annual member." This distinction is essential for my comparative analysis.
#
# **Geographic Data (Potentially)**: Depending on the dataset, it may include latitude and longitude coordinates for the start and end stations, which can be used for spatial analysis and mapping.
#
# **Bike Type**: the data also contains the type of bike used for the trip.
#
# **Data Period**: The data covers a specific twelve-month period,from January 2024 - Decemeber 2024. Specifying the time frame is critical for understanding seasonal trends and potential biases.
#
# **Volume:** The data contains a large number of trip records, providing a robust foundation for statistical analysis.
#
# **Variables Commonly Found in the Data**:
#
# **ride_id**: A unique identifier for each bike trip.
#
# **rideable_type**: The type of bike used (e.g., classic bike, electric bike, docked bike).
#
# **started_at**: The date and time the trip started.
#
# **ended_at**: The date and time the trip ended.
#
# **start_station_name**: The name of the starting station.
#
# **start_station_id**: The unique identifier of the starting station.
#
# **end_station_name**: The name of the ending station.
#
# **end_station_id**: The unique identifier of the ending station.
#
# **start_lat**: Latitude of the starting station.
#
# **start_lng**: Longitude of the starting station.
#
# **end_lat**: Latitude of the ending station.
#
# **end_lng**: Longitude of the ending station.
#
# **member_casual**: Indicates whether the rider is a member or casual rider.
#
# **Importance of Data Description**:
#
# Clearly describing the data is essential for:
# * Ensuring the analysis is reproducible.
# * Providing context for the findings.
# * Identifying potential limitations or biases in the data.
# * Allowing others to understand the source of the analysis.
#
# ## Key stakeholders:
#
# * **Cyclistic**: A bike-share program that features more than 5,800 bicycles and 600
# docking stations. Cyclistic sets itself apart by also offering reclining bikes, hand
# tricycles, and cargo bikes, making bike-share more inclusive to people with disabilities
# and riders who can’t use a standard two-wheeled bike.
#
# * **Lily Moreno**: The director of marketing and your manager. Moreno is responsible for
# the development of campaigns and initiatives to promote the bike-share program.
# These may include email, social media, and other channels.
#
# * **Cyclistic marketing analytics team**: A team of data analysts who are responsible for
# collecting, analyzing, and reporting data that helps guide Cyclistic marketing strategy.
# I joined this team six months ago and have been busy learning about Cyclistic’s
# mission and business goals—as well as how I, as a junior data analyst, can help
# Cyclistic achieve them.
#
# * **Cyclistic executive team**: The notoriously detail-oriented executive team will decide
# whether to approve the recommended marketing program.
#
# ## About the company
#
# In 2016, Cyclistic launched a successful bike-share offering. Since then, the program has grown
# to a fleet of 5,824 bicycles that are geotracked and locked into a network of 692 stations across
# Chicago. The bikes can be unlocked from one station and returned to any other station in the
# system anytime.
# Until now, Cyclistic’s marketing strategy relied on building general awareness and appealing to
# broad consumer segments. One approach that helped make these things possible was the
# flexibility of its pricing plans: single-ride passes, full-day passes, and annual memberships.
# Customers who purchase single-ride or full-day passes are referred to as casual riders.
# Customers who purchase annual memberships are Cyclistic members.
# Cyclistic’s finance analysts have concluded that annual members are much more profitable
# than casual riders. Although the pricing flexibility helps Cyclistic attract more customers,
# Moreno believes that maximizing the number of annual members will be key to future growth.
# Rather than creating a marketing campaign that targets all-new customers, Moreno believes
# there is a solid opportunity to convert casual riders into members. She notes that casual riders
# are already aware of the Cyclistic program and have chosen Cyclistic for their mobility needs.
# Moreno has set a clear goal: Design marketing strategies aimed at converting casual riders into
# annual members. In order to do that, however, the team needs to better understand how
# annual members and casual riders differ, why casual riders would buy a membership, and how
# digital media could affect their marketing tactics. Moreno and her team are interested in
# analyzing the Cyclistic historical bike trip data to identify trends.
#
#
# ## Sourced data
#
# To complete this project I used Cyclistic historical data to analyze and identify and analyse trends. However, Cyclistic is a functional company, the data is real and is made available by Motivate International Inc. as per licence agreement. I chose to work with twelve months of data, from January 2024 - December 2024, because the timeframe is critical for understanding seasonal trends and potential biases. Note that data-privacy issues prohibit me from using riders’ personally identifiable information. This means that I won’t be able to connect pass purchases to credit card numbers to determine if casual riders live in the Cyclistic service area or if they have purchased multiple single passes.
#
# I started by downloading twelve months of rider data and uploading it to my Google Cloud Storage Bucket. The data was collected, stored and protected by Cyclistic in a secure company database. The data was stored in a CSV. format and is reliable, original, comprehensive, current and cited. I believe the data to be reliable and unbiased as each line of the data contains the ride data for every single bike ride taken during each month.
#
# # Prepare; Phase
#
#
# After downloading the data I uploaded it to my Google Cloud Storage bucket, where I labeled the bucket for easy accessibility. I continued to create a new project in BigQuery where I then created twelve individual tables that hold the bike ride data for 2024. I then prepared the data in a three step process. One, combining the data by appending the twelve datasets to create a new data set for the whole year. Two, performing some basic exploration. Three, cleaning the data for further analysis. Each step is listed below:
#
#
# Part 1: Data Integration and Storage:
#
# * Download the data from the Divvy Bike Trip Database.
# * Create a Google CLoud Storage (GSC) bucket and upload the 12 datasets.
# * This is done because the datasets are too big to load directly into a BigQuery project.
# * Label bucket accordingly for easy access.
# * Create a new project in BigQuery and label it for easy access.
# * Create twelve individual tables in BigQuery, each holding bike ride data for a specific month of 2024.
#
# Part 2: Data Preparation - Combining and Exploration:
#
# * Combining data: Append twelve individual BigQuery tables into a single, comprehensive dataset representing the entire year of 2024.
# * Basic:exploration: Perform initial data exploration to understand the data structure and characteristics. Identify potential data quality issues or anomalies.
# * I checked that the number of rows in the new data set equals the number of rows in each individual dataset. There are 5,860,568 rows and 13 columns.
#
#
#
# Part 3: Data Preparation - Cleaning:
#
# * Clean the combined dataset to ensure data quality for further analysis.
# * This includes: Handling missing data, correcting data inconsistencies, removing duplicate records, standardizing data formats and filtering out unwanted data.

# %%
#@title Join tables to create tripdata_2024 table
## This query is part of of the data preparation steps outlined above.

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.tripdata_2024` AS
SELECT
  ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
 `fit-oasis-417114.Bike_share_case_study.202401_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202402_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202403_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202404_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202405_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202406_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202407_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202408_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202409_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202410_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202411_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024

UNION ALL

SELECT

 ride_id,
  rideable_type,
  started_at,
  ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
`fit-oasis-417114.Bike_share_case_study.202412_tripdata`
WHERE EXTRACT(YEAR FROM started_at) = 2024;

# %%
#@title Data Eploration With SQL
--- Chech the schema of ridedata_2024 table---

SELECT * FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`  LIMIT 0;

---Row count---

SELECT COUNT (*) FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`;

## Number of rows 5860568

---Missing values---

SELECT
 COUNT(*) - COUNT(ride_id) AS missing_ride_id,
 COUNT(*) - COUNT(rideable_type) AS missing_rideable_type,
 COUNT(*) - COUNT(started_at) AS MISSING_started_at,
 COUNT (*) - COUNT(ended_at) AS missing_ended_at,
 COUNT (*) - COUNT(start_station_name) AS mising_start_station_name,
 COUNT (*) - COUNT(start_station_id) AS missing_start_station_id,
 COUNT(*) - COUNT(end_station_name) AS missing_end_station_name,
 COUNT (*) - COUNT(end_station_id) AS missing_end_station_id,
 COUNT (*) - COUNT(start_lat) AS missing_start_lat,
 COUNT(*) - COUNT(start_lng) AS missing_start_lng,
 COUNT (*) - COUNT(end_lat) AS missing_end_lat,
 COUNT (*) - COUNT(end_lng) AS missing_end_lng,
 COUNT(*) - COUNT(member_casual) AS missing_member_casual,
FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`;

## This query creted a table that displyes the missing values in the respected coloumn.
## There are 1073951 missing values in start_station_name and start_station_id columns.
## There are 1104653 missing values in th end_station_name and end_station_id columns

---Checking for duplicate rows using ride_id----

SELECT
  ride_id,
  COUNT(*) AS duplicate_count
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
GROUP BY
  ride_id
HAVING
  COUNT(*) > 1;


--- Cheching the number of characters for rider_id

SELECT
  LENGTH(ride_id) AS ride_id_length,
  COUNT(*) AS count_of_ids
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
GROUP BY
  ride_id_length
ORDER BY
  ride_id_length;

## Query results show that all 5860568 id's have 16 characters.

--- Rideable Type Analysis---

SELECT rideable_type,
COUNT (*) FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
GROUP BY rideable_type;

## There are three types of ridable bikes: electric bikes, electric scooter and classic bikes.

---Member vs. Casual Riders---

SELECT member_casual,
COUNT (*) AS ride_count,
FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
GROUP BY member_casual;

## The ride count for casual riders are 2151658 and the ride count for members are 3708910 for the year of 2024.

---Data Type Validation---

## Ensure data types are correct (e.g., timestamps are valid, latitude/longitude are within expected ranges).

SELECT COUNT(*)
FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
WHERE start_lat > 90 OR START_LAT <-90;

## The result is 0 meaning that the time stamp are valid and th latitude/longitude are within ranges.

---Ride Duration---

SELECT TIMESTAMP_DIFF(ended_at, started_at, MINUTE) AS ride_duration_minutes,
count (*) FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
GROUP BY ride_duration_minutes
ORDER BY ride_duration_minutes;

## Check to see if there is any rides shorter than a minute or longer than a day.

SELECT
COUNT(CASE WHEN TIMESTAMP_DIFF(ended_at, started_at, SECOND) < 60 THEN 1 ELSE NULL END) AS rides_les_than_minute,
COUNT(CASE WHEN TIMESTAMP_DIFF(ended_at, started_at, SECOND) < 86400 THEN 1 ELSE NULL END) AS rides_longer_than_day,
FROM
`fit-oasis-417114.Bike_share_case_study.tripdata_2024`

## There are 131530 rides < 1 minute and 5852972 rides > than a day.

# %%
#@title Data cleaning With SQL

## 1. Identify and Handle Missing Values:

SELECT
  COUNT(*) - COUNT(ride_id) AS missing_ride_id,
  COUNT(*) - COUNT(rideable_type) AS missing_ridable_type,
  COUNT(*) - COUNT(started_at) AS missing_started_at,
  COUNT(*) - COUNT(ended_at) AS missing_ended_at,
  COUNT(*) - COUNT(start_station_name) AS missing_start_station_name,
  COUNT(*) - COUNT(start_station_id) AS missing_start_station_id,
  COUNT(*) - COUNT(end_station_name) AS missing_end_station_name,
  COUNT(*) - COUNT(end_station_id) AS missing_end_station_id,
  COUNT(*) - COUNT(start_lat) AS missing_start_lat,
  COUNT(*) - COUNT(start_lng) AS missing_start_lng,
  COUNT(*) - COUNT(end_lat) AS missing_end_lat,
  COUNT(*) - COUNT(end_lng) AS missing_end_lng,
  COUNT(*) - COUNT(member_casual) AS missing_member_casual,
FROM
`fit-oasis-417114.Bike_share_case_study.tripdata_2024`;

## Handle missing values: There are only a small number of missing values therefor it can be filtered out.

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned` AS
SELECT * FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
WHERE ride_id IS NOT NULL
  AND started_at IS NOT NULL
  AND ended_at IS NOT NULL
  AND start_station_name IS NOT NULL
  AND start_station_id IS NOT NULL
  AND end_station_name IS NOT NULL
  AND end_station_id IS NOT NULL
  AND start_lat IS NOT NULL
  AND start_lng IS NOT NULL
  AND end_lat IS NOT NULL
  AND end_lng IS NOT NULL
  AND member_casual IS NOT NULL;

## This query creates a new table that excluded the all the Null values.

## 2. Address Data Type Issues:

## Verify data type:

SELECT * FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024` LIMIT 10;

## Correct Data Types: Use CAST() or PARSE_DATE(), PARSE_TIMESTAMP() to convert data types.

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned` AS
SELECT
  ride_id,
  rideable_type,
  PARSE_TIMESTAMP('%Y-%m-%d %H:%M:%E*S%Ez', CAST(started_at AS STRING)) AS started_at,
  PARSE_TIMESTAMP('%Y-%m-%d %H:%M:%E*S%Ez', CAST(ended_at AS STRING)) AS ended_at,
  start_station_name,
  start_station_id,
  end_station_name,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024`;

## 3. Remove any duplicate records:

SELECT ride_id, COUNT(*)
FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
GROUP BY ride_id
HAVING COUNT(*) > 1;

## After identifying the duplicte will now be removed.

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned` AS
SELECT * EXCEPT(row_num)
FROM(
  SELECT *, ROW_NUMBER() OVER (PARTITION BY ride_id ORDER BY started_at) AS row_num FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
)
WHERE row_num = 1;

## This query removed all the duplicate rows and kept only the first instances.

## 4. Handle outliers:

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned` AS
SELECT *
FROM `fit-oasis-417114.Bike_share_case_study.tripdata_2024`
WHERE TIMESTAMP_DIFF(ended_at, started_at, MINUTE) BETWEEN 1 AND 1440;

## This query removes rides that are less than a minute and more than a day.

## 5. Standardize text data:

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned` AS
SELECT
 ride_id,
 rideable_type,
 started_at,
 ended_at,
 TRIM(start_station_name) AS start_station_name,
 TRIM(end_station_name) AS end_station_name,
  start_station_id,
  end_station_id,
  start_lat,
  start_lng,
  end_lat,
  end_lng,
  member_casual
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024`


## This query removes any whitespaces from string columns.

# %%
#@title Tables for Tableau

## The following queries will be used to extract tables for use in Tableau for creating visualizations.

##1. Daily Ride Counts and Member/Casual Breakdown:

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.daily_rides_summary_cleaned` AS
SELECT
  EXTRACT(DATE FROM started_at) AS ride_date,
  COUNT(*) AS total_rides,
  COUNT(CASE WHEN member_casual = 'member' THEN 1 ELSE NULL END) AS member_rides,
  COUNT(CASE WHEN member_casual = 'casual' THEN 1 ELSE NULL END) AS casual_rides
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
GROUP BY
  ride_date
ORDER BY
  ride_date;

## 2. Hourly ride counts

  CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.hourly_rides_summary_cleaned` AS
SELECT
  EXTRACT(HOUR FROM started_at) AS ride_hour,
  COUNT(*) AS total_rides
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
GROUP BY
  ride_hour
ORDER BY
  ride_hour;

## 3. Start station popularity

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.start_station_popularity_cleaned` AS
SELECT
  start_station_name,
  COUNT(*) AS start_count
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
WHERE start_station_name IS NOT NULL
GROUP BY
  start_station_name
ORDER BY
  start_count DESC;

## 4. End station popularity

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.end_station_popularity_cleaned` AS
SELECT
  end_station_name,
  COUNT(*) AS end_count
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
WHERE end_station_name IS NOT NULL
GROUP BY
  end_station_name
ORDER BY
  end_count DESC;

## 5. Rideable Type Usage

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.rideable_type_usage_cleaned` AS
SELECT
  rideable_type,
  COUNT(*) AS ride_count,
  COUNT(CASE WHEN member_casual = 'member' THEN 1 ELSE NULL END) AS member_count,
  COUNT(CASE WHEN member_casual = 'casual' THEN 1 ELSE NULL END) AS casual_count
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
GROUP BY
  rideable_type;

## 6. Average Ride Duration by User Type

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.avg_ride_duration_user_type_cleaned` AS
SELECT
  member_casual,
  AVG(TIMESTAMP_DIFF(ended_at, started_at, MINUTE)) AS avg_duration_minutes
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
GROUP BY
  member_casual;

## 7. Top start locations

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.top_10_start_locations` AS
SELECT
  start_station_name,
  start_lat,
  start_lng,
  COUNT(*) AS start_count
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
WHERE
  start_station_name IS NOT NULL AND start_lat IS NOT NULL AND start_lng IS NOT NULL
GROUP BY
  start_station_name, start_lat, start_lng
ORDER BY
  start_count DESC
LIMIT 10;

## 8. Top end locations

CREATE OR REPLACE TABLE `fit-oasis-417114.Bike_share_case_study.top_10_end_locations` AS
SELECT
  end_station_name,
  end_lat,
  end_lng,
  COUNT(*) AS end_count
FROM
  `fit-oasis-417114.Bike_share_case_study.tripdata_2024_cleaned`
WHERE
  end_station_name IS NOT NULL AND end_lat IS NOT NULL AND end_lng IS NOT NULL
GROUP BY
  end_station_name, end_lat, end_lng
ORDER BY
  end_count DESC
LIMIT 10;

# %% [markdown]
# # Analysis; Phase
#
# After exploring and cleaning the data I used Bigquery to create additional tables that I then imported to Tableau to create visualization to better understand the difference in use of ride-share bikes among casual users and members.
#
# Following some key takeaways and visualization from my Tableau findings:
#
# 1. Members where resposible for 62.8% of bike rides.
# ![Number of riders by user type.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. The hourly ride data reveals distinct peaks in bike sharing usage at 8 am and between 4 and 6 pm. These peaks strongly suggest that members utilize the service for commuting, with 8 am representing the typical start of the workday and 5 pm the end. Additionally, the afternoon increase may reflect casual users enjoying the service for leisure activities, such as sunset bike rides. The low usage during the very early morning hours also indicates that the bikes are mainly used during the day.![Hourly Rides.png](data:image/png;base64,...)

# %% [markdown]
# 3.  The total rides per month exhibit a clear seasonal trend, with ridership peaking during the warmer months of June through September. Notably, September shows the highest number of rides, potentially due to continued favorable weather, the start of the academic year, or local events. Both casual and member rides follow this trend, but casual rides demonstrate a more pronounced increase during the peak. Ridership more than doubles from the winter months to the summer peak, highlighting the service's strong weather dependency. Conversely, the colder months from December to February show significantly lower ridership. The transition months of April and October reveal sharp changes, indicating a rapid adoption of the service as weather improves and a quick decline as it worsens.
# .![Total rides per month.png](data:image/png;base64,...)

# %% [markdown]
# 4. Both casual users and members preferred using electric bikes with almost 3 million rides for 2024, classic bikes was the second most popular choice among users  with more than 2.7 million rides and the least popular was electric scooters showing a significantly lower count with only about 150 thousand rides.
# ![Rideable type count.png](data:image/png;base64,...)

# %% [markdown]
# 5. The daily ride summary reveals a stark contrast between member and casual user behavior. The red graph shows a significantly higher usage of bikes by members during the weekdays, from Monday to Friday. This strongly suggests that members primarily utilize the service for commuting, a conclusion further supported by the observed peaks in hourly usage at 8 am and 5 pm. Conversely, the orange graph demonstrates a dramatic increase in usage by casual users on Saturdays and Sundays. This indicates that casual users primarily use the bike-sharing service for leisure and recreational activities during the weekends.
# ![Rides By Day Of The Week.png](data:image/png;base64,...)

# %% [markdown]
# 6.The map indicating the top 10 start and end stations indicate that most users make use of the bike sharing service from State st and Chicago Ave. This is a popular shopping street according to Envisionit (2022). There is also a popular pier where big events take place called Navy Pier. This clearly indicates that this is a popular destination filled with restaurants, bars and shops enjoyed by both tourists and locals. The Start and end station popularity is indicated by the size of the dot indicating the location of the stations.
#
# Top Start Station: ![Start Station Map.png](data:image/png;base64,...)

# %% [markdown]
# Top End Station:
# ![End Station Map.png](data:image/png;base64,...)

# %% [markdown]
# ### Share; Phase
#
# **Summary**:
#
# This report analyzes bike-sharing data to understand user behavior, seasonal trends, and rideable type preferences. Key findings indicate distinct usage patterns between members (weekday commuters) and casual users (weekend leisure riders). Ridership peaks during the summer months, potentially driven by favorable weather and local events. Electric bikes are the most popular rideable type. These insights can inform targeted marketing campaigns, operational adjustments, and service enhancements.
#
# **User Behavior**:
#
# **Members**: Primarily use the service for weekday commuting, with peak usage at 8 am and 5 pm. Weekday ridership is significantly higher than weekend ridership.
# **Casual Users**: Primarily use the service for leisure and recreation, with peak usage on weekends.
#
# **Seasonal Trends**:
# Ridership peaks during the summer months (June-September), with September showing the highest usage. This peak is likely due to a combination of favorable weather, the start of the academic year, and local events.
#
# **Rideable Type Preferences**:
#
# Electric bikes are the most popular choice among both members and casual users, followed by classic bikes. Electric scooters show significantly lower usage.

# %% [markdown]
# **Recommendations**:
#
# Based on the analysis of the bike sharing data, I have identified key trends and potential service offerings and the number of rides:
#
# 1. Annual weekend memberships can be offered for city residents and individuals in surrounding areas seeking leisure and  recreational activities. Offering unlimited weekday rides, potential discounts on bike rentals and tours, and access to exclusive events. The marketing strategy can focus on targeted campaigns in the surrounding area highlighting the affordability and convenience of weekend bike trips.
#
# 2. Summer membership can be offered from the 1 st of June to August 31st. Providing unlimited rides, potential discounts and access to exclusive events. Marketing campaigns can start in late spring, emphasising the enjoyment of the city with unlimited bike access during summer.
#
# 3. A weekly summer pass catering to tourists and visitors with options for single or multi_week passes can be offered. This offer should be easy to purchase through a website, mobile app or kiosks. Collaboration with hotels, tourist attractions, and local businesses can be formed to offer promotions.
#
# 4. Targeted marketing strategies can be implemented focusing on spring and summer months, launching campaigns in early springs. Concentrating on the top starting and ending locations for casual users, partnering with local businesses or using geofencing campaigns Semrush Blog. (n.d.). Social media, SEO, and other online advertising can be utilized to market engaging content showcasing the benefits of bike sharing for leisure and recreation.
#
# **Additional Recommendations**:
#
# * **User Research**: Conduct surveys and focus groups to gather user feedback and identify unmet needs.
# * **Partnerships**: Explore collaborations with local businesses, tourism organizations, and event organizers for expanded reach and bundled packages.
# * **Sustainability Initiatives**: Promote the environmental benefits of bike-sharing and implement sustainability initiatives.
# * **Technology Integration**: Integrate new technologies like smart bikes and gamification features Bullock, M. (2022) to enhance user experience and data collection.
#
# By implementing these recommendations, the bike-sharing service can effectively cater to diverse user needs, capitalize on seasonal trends, and promote sustainable transportation options.

# %% [markdown]
# Resources:
#
# divvy-tripdata.s3.amazonaws.com. (n.d.). Bucket loading... [online] Available at: https://divvy-tripdata.s3.amazonaws.com/index.html.
#
# Envisionit (2022). State Street Shopping Guide | Choose Chicago. [online] Choose Chicago. Available at: http://choosechicago.com/articles/shopping-and-fashion/your-chicago-state-street-shopping-guide/ [Accessed 9 Mar. 2025].
#
# Hodges, A. (2023). Google Data Analytics Cyclistic Bike-Share Case Study. [online] Medium. Available at: https://medium.com/google-data-analytics-cyclistic-bike-share-case/cyclistic-bike-share-case-study-8edfa9217a06 [Accessed 9 Mar. 2025].
#
# Hotels.com. (2025). State Street in Chicago - Enjoy Shopping on ‘That Great Street’ - Go Guides. [online] Available at: https://www.hotels.com/go/usa/state-street-chicago [Accessed 9 Mar. 2025].
#
# Navy Pier. (n.d.). Home. [online] Available at: https://navypier.org/.
#
# Semrush Blog. (n.d.). Improve Your ROAS with Geofencing Marketing. [online] Available at:
#
# https://www.semrush.com/blog/geofencing-marketing/.
